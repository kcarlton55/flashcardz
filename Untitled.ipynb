# %%
c()
# Out:
#   0. chapa SF             (t: 9)    12. ruda nf              (t: 6)    24. voltear vi           (t: 1)
#   1. ornitorrinco nm      (t: 8)    13. hortaliza nf         (t: 6)    25. liga de cabello      (t: 1)
#   2. mimeógrafo nm        (t: 8)    14. estrechar            (t: 6)    26. mariachi nm          (t: 1)
#   3. ceceo nm             (t: 8)    15. acechar vtr          (t: 6)    27. collie barbudo       (t: 1)
#   4. trineo nm            (t: 7)    16. quisquilloso         (t: 5)    28. caparazón nm         (t: 0)
#   5. alocado adj          (t: 7)    17. palco nm             (t: 3)    29. desenvuelto adj      (t: 0)
#   6. asilo nm             (t: 7)    18. hipódromo nm         (t: 5)    30. alarde nm            (t: 0)
#   7. tapadera nf          (t: 4)    19. risotto n            (t: 5)    31. cuñado, -da nm, nf   (t: 0)
#   8. cacofonía nf         (t: 6)    20. bellaco, -ca nm, nf  (t: 3)    32. excuñado, -da nm, nf (t: 0)
# ...

# %%
add('malabarismo nm',
'''
(arte de destreza)            juggling n

Mi primo practica el malabarismo lanzando pelotas al aire.
My cousin practices juggling balls.

figurado (acción ingeniosa)  <u>juggling act<> n

Las familias numerosas deben hacer malabarismos para llegar a fin de mes.
Big families must do juggling acts to make it to the end of the month.''')
# Out:
# malabarismo nm
#
# (arte de destreza)            juggling n
#
# Mi primo practica el malabarismo lanzando pelotas al aire.
# My cousin practices juggling balls.
#
# figurado (acción ingeniosa)  juggling act n
#
# Las familias numerosas deben hacer malabarismos para llegar a fin de mes.
# Big families must do juggling acts to make it to the end of the month.
#
# Number of cards now at:  37
