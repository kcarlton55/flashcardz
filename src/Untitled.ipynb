# %%
add('collie barbudo', '[bearded collie](https://www.purina.es/encuentra-mascota/razas-de-perro/collie-barbudo)')
# Out:
# collie barbudo
#
# [bearded collie](https://www.purina.es/encuentra-mascota/razas-de-perro/collie-barbudo)
#
# Number of cards now at:  35

# %%
c(34,[1])
